# %% [raw]
# layer by layer ???

# %%
import numpy as np
from PIL import Image
from typing import List

from src.hider.core import image_in_image

# %%
original_image = "https://www.google.com/earth/studio/assets/static/images/social.jpg"
memes = [#"https://derekbruff.org/blogs/fywscrypto/files/2018/06/Romy-Digital-Steganography.jpg",
         "https://i.redd.it/0ayqdn07ma851.png",
         "https://memegenerator.net/img/instances/24818335/not-sure-if-its-steganography-or-ancient-witchcraft.jpg",
         "https://sd.keepcalms.com/i-w600/don-t-worry-your-secret-is-safe-with-me.jpg"]
image_urls = [original_image] + memes

# %%
image = image_in_image(*image_urls, key=135)

# %%
hidden_images = image_in_image(image, key=135)

# %%
hidden_images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F315BCF3A30>

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1200 at 0x7F315BCEF970>
